# %%
import pandas as pd

data = pd.read_csv ("../results/results.csv")

display (data)
# Out:
#     Epoch  Train Loss  Test Loss  Train Accuracy  Test Accuracy  \
# 0     1.0     1.20796    0.65524        86.34777       93.13501
# 1     2.0     0.70657    0.49632        91.95182       94.27918
# 2     3.0     0.55786    0.45761        93.68017       94.27918
# 3     4.0     0.46379    0.41924        94.90223       95.57590
# 4     5.0     0.40183    0.39124        95.37360       95.65217
# 5     6.0     0.38134    0.37405        95.65293       96.10984
# 6     7.0     0.29051    0.29431        96.49092       97.33028
# 7     8.0     0.28793    0.32405        96.73534       96.56751
# 8     9.0     0.27621    0.23923        96.68296       97.48284
# 9    10.0     0.30359    0.26217        96.63059       97.33028
# 10   11.0     0.24573    0.24276        97.01466       97.10145
# 11   12.0     0.22965    0.18628        97.24162       98.01678
# 12   13.0     0.21388    0.27481        97.43366       97.40656
# 13   14.0     0.20710    0.24045        97.53841       98.39817
# ...

# %%
data['Time (Train)'].sum ()
# Out:
# 41.42748403549194
