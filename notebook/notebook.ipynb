# %%
import pandas as pd

data = pd.read_csv ("../results/results.csv")

data
# Out:
#    Epoch  Train Loss  Test Loss  Train Accuracy  Test Accuracy  \
# 0      1     0.01506    0.03557        89.02778       89.12882
# 1      2     0.01051    0.03070        94.28819       92.03276
# 2      3     0.00834    0.03651        96.61458       88.83098
# 3      4     0.00855    0.02859        96.37153       94.19211
# 4      5     0.00770    0.03084        97.69097       93.14966
# 5      6     0.00722    0.02580        98.05556       97.54281
# 6      7     0.00731    0.02580        97.70833       97.69173
# 7      8     0.00659    0.03240        98.55903       90.91586
# 8      9     0.00677    0.03509        98.62847       90.69248
# 9     10     0.00689    0.04824        98.26389       81.98064
#
#    Correct Predictions (Train)  Incorrect Predictions (Train)  \
# 0                     89.02778                      -88.02778
# 1                     94.28819                      -93.28819
# 2                     96.61458                      -95.61458
# ...

# %%
data['Time (Train)'].sum ()
# Out:
# 3814.1820100000004
