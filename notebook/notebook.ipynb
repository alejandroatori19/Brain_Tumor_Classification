# %%
import pandas as pd

data = pd.read_csv ("../results/results.csv")

data.head ()
# Out:
#    Epoch  Train Loss  Test Loss  Train Accuracy  Test Accuracy  \
# 0    1.0         1.0        1.0           100.0          100.0
# 1    2.0         1.0        1.0           100.0          100.0
# 2    3.0         1.0        1.0           100.0          100.0
# 3    4.0         1.0        1.0           100.0          100.0
# 4    5.0         1.0        1.0           100.0          100.0
#
#    Correct Predictions (Train)  Incorrect Predictions (Train)  \
# 0                        100.0                          -99.0
# 1                        100.0                          -99.0
# 2                        100.0                          -99.0
# 3                        100.0                          -99.0
# 4                        100.0                          -99.0
#
#    Correct Predictions (Test)  Incorrect Predictions (Test)  Time (Train)  \
# 0                       100.0                         -99.0      22.77881
# ...
