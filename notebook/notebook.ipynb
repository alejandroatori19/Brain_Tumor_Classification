# %%
import pandas as pd

data = pd.read_csv ("../results/results.csv")

display (data)
# Out:
#    Epoch  Train Loss  Test Loss  Train Accuracy  Test Accuracy  \
# 0      1     1.05021    0.61154        87.63966       92.90618
# 1      2     0.50960    1.48816        94.04679       84.21053
# 2      3     0.33809    1.25727        95.82751       84.89703
# 3      4     0.32859    0.28540        96.24651       96.56751
# 4      5     0.21167    0.34892        97.22416       96.49123
# 5      6     0.14484    0.21878        98.32402       97.55912
# 6      7     0.16382    0.61435        98.11453       93.66895
# 7      8     0.13412    0.30740        98.53352       97.02517
# 8      9     0.10487    0.14740        98.70810       98.32189
# 9     10     0.05986    0.30729        99.09218       96.94889
#
#    Correct Predictions (Train)  Incorrect Predictions (Train)  \
# 0                     87.63966                       12.36034
# 1                     94.04679                        5.95321
# 2                     95.82751                        4.17249
# ...

# %%
data['Time (Train)'].sum ()
# Out:
# 3814.1820100000004
